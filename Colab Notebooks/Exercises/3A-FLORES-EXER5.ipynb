# %% [markdown]
#  Topic 5: Logistic Regression Week No. 6
# Course Code: CSEL302
# Term: 2nd Semester
# Course Title: Introduction to Intelligent Systems Academic Year: 2023-2024
# Student Name: Flores Edrian B.
# Section: BSCS 3A
# Due date: March 6, 2024

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler


# Load the dataset into a Pandas DataFrame
df = pd.read_csv('/content/BankCustomerData.csv')

# Convert categorical variables into dummy variables
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome']
df_categories = df[categorical_cols]
df_dummies = pd.get_dummies(df_categories, drop_first = True)
df_dummies['term_deposit'] = df['term_deposit'].map ({'yes': 1, 'no': 0})

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = df_dummies.drop('term_deposit', axis=1)
y = df_dummies['term_deposit']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
scaler = StandardScaler()
x_train_scaled= scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LogisticRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test_scaled)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test,y_pred)

print(f'accuracy: {accuracy}')
print("Confusion Matrix: ")
print(conf_matrix)
print("Classification Report: ")
print(class_report)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
report = """
Analysis Report

1. Model Performance Evaluation:
    Accuracy: {:.2f}

2. Confusion Matrix:
    {}

3. Classification Report:
    {}

""".format(accuracy, conf_matrix, class_report)

print(report)

# %% [markdown]
# Conclusion:
#
# The logistic regression model accurately predicts whether customers will subscribe to term deposits.
#
# - Targeted Marketing: The bank can focus its marketing efforts on customers more likely to subscribe, improving campaign effectiveness.
#
# - Efficient Resource Allocation: By allocating resources based on customer preferences, the bank can optimize its budget and manpower.
#
# - Enhanced Customer Relationships: Personalized offers for potential subscribers can improve customer satisfaction and loyalty.
#
# - Effective Risk Management: Identifying low-probability subscribers helps the bank mitigate risk and optimize portfolio management.
#
# Overall, leveraging insights from the model enables the bank to make informed decisions, enhance customer engagement, and achieve its business goals.
